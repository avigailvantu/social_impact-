# %%
import glob
import os
import json
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# prep: reading both csv files

# %%
dis = pd.read_csv("DistrictsLevelData.csv")
school = pd.read_csv("SchoolLevelData.csv")
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
dis.head(2)
# Out:
#                          Agency Name  \
# 0  100 LEGACY ACADEMY CHARTER SCHOOL
# 1   21ST CENTURY CHARTER SCH OF GARY
#
#   State Name [District] Latest available year  \
# 0                                  New Jersey
# 1                                     Indiana
#
#   State Abbr [District] Latest available year  \
# 0                                         NJ
# 1                                         IN
#
#    Agency ID - NCES Assigned [District] Latest available year  \
# 0                                            3400743
# 1                                            1800046
#
#    Total Number Operational Schools [Public School] 2013-14  \
# 0                                                  0
# 1                                                  1
#
#    Total Number Operational Charter Schools [Public School] 2013-14  \
# 0                                                  0
# 1                                                  1
#
#    Total Number of Public Schools [Public School] 2013-14  \
# 0                                                NaN
# 1                                                  1
#
#   Agency Type [District] 2013-14 Urban-centric Locale [District] 2013-14  \
# 0        7-Charter school agency                          11-City: Large
# 1        7-Charter school agency                          13-City: Small
#
#   Metro Micro Area Code [District] 2013-14    ...      \
# 0                      1-Metropolitan Area    ...
# 1                      1-Metropolitan Area    ...
#
#   White Students [Public School] 2013-14  \
# 0                                    NaN
# 1                                      0
#
#   Hawaiian Nat./Pacific Isl. Students [Public School] 2013-14  \
# 0                                                NaN
# 1                                                  0
#
#    Two or More Races Students [Public School] 2013-14  \
# 0                                                NaN
# 1                                                  9
#
#    Full-Time Equivalent (FTE) Teachers [District] 2013-14  \
# 0                                                NaN
# 1                                                  1
#
#    Full-Time Equivalent (FTE) Teachers [Public School] 2013-14  \
# 0                                                NaN
# 1                                                  1
#
#    Pupil/Teacher Ratio [District] 2013-14  \
# 0                                     NaN
# 1                                     632
#
#    Pupil/Teacher Ratio [Public School] 2013-14  \
# 0                                          NaN
# 1                                          632
#
#    Kindergarten Teachers [District] 2013-14  \
# 0                                       NaN
# 1                                         0
#
#    Elementary Teachers [District] 2013-14  agency_id
# 0                                     NaN    3400743
# 1                                       0    1800046
#
# [2 rows x 40 columns]

# %%
#get some info
print "districts",len(dis)
print "schools", len(school)
# Out:
# districts 18567
# schools 99074

# %%
school.columns
# Out:
# Index([u'School Name', u'State Name [Public School] Latest available year',
#        u'State Abbr [Public School] Latest available year', u'studyID',
#        u'instudy',
#        u'School ID - NCES Assigned [Public School] Latest available year',
#        u'Agency Name [Public School] 2013-14',
#        u'Agency ID - NCES Assigned [Public School] Latest available year',
#        u'School Type [Public School] 2013-14',
#        u'Agency Type [District] 2013-14',
#        u'Operational Status [Public School] 2013-14',
#        u'Charter School [Public School] 2013-14',
#        u'Magnet School [Public School] 2013-14',
#        u'Urban-centric Locale [Public School] 2013-14',
#        u'School-wide Title I [Public School] 2013-14',
#        u'Title I Eligible School [Public School] 2013-14',
#        u'Title I School Status [Public School] 2013-14',
#        u'School Level Code [Public School] 2013-14',
#        u'Lowest Grade Offered [Public School] 2013-14',
#        u'Highest Grade Offered [Public School] 2013-14',
#        u'Kindergarten offered [Public School] 2013-14',
#        u'Grade 1 offered [Public School] 2013-14',
#        u'Grade 2 offered [Public School] 2013-14',
#        u'Grade 3 offered [Public School] 2013-14',
#        u'Grade 4 offered [Public School] 2013-14',
#        u'Grade 5 offered [Public School] 2013-14',
#        u'Grade 6 offered [Public School] 2013-14',
#        u'Total Students [Public School] 2013-14',
#        u'Total Free and Reduced Lunch Students [Public School] 2013-14',
#        u'Kindergarten Students [Public School] 2013-14',
#        u'Grade 1 Students [Public School] 2013-14',
#        u'Grade 2 Students [Public School] 2013-14',
#        u'Grade 3 Students [Public School] 2013-14',
#        u'Grade 4 Students [Public School] 2013-14',
#        u'Grade 5 Students [Public School] 2013-14',
#        u'Grade 6 Students [Public School] 2013-14',
#        u'Male Students [Public School] 2013-14',
#        u'Female Students [Public School] 2013-14',
#        u'American Indian/Alaska Native Students [Public School] 2013-14',
#        u'Asian or Asian/Pacific Islander Students [Public School] 2013-14',
#        u'Hispanic Students [Public School] 2013-14',
#        u'Black Students [Public School] 2013-14',
#        u'White Students [Public School] 2013-14',
#        u'Hawaiian Nat./Pacific Isl. Students [Public School] 2013-14',
#        u'Two or More Races Students [Public School] 2013-14',
#        u'Full-Time Equivalent (FTE) Teachers [Public School] 2013-14',
#        u'Pupil/Teacher Ratio [Public School] 2013-14'],
#       dtype='object')

# %%
#changing columns name to fit to the python structure 

school['school_type'] = school['School Type [Public School] 2013-14'] 
school['grade']= school['Highest Grade Offered [Public School] 2013-14']
school['school_level'] = school['School Level Code [Public School] 2013-14']

# %% [markdown]
# understand the data in order to filter through level of education given in institution x

# %%
school.grade.unique()
# Out:
# array(['12th Grade', '8th Grade', '6th Grade', '5th Grade', '3rd Grade',
#        '2nd Grade', '10th Grade', '1st Grade', nan, '4th Grade',
#        'Kindergarten', '9th Grade', '7th Grade', '11th Grade',
#        'Prekindergarten', 'Ungraded'], dtype=object)

# %%
# School level is the column which specify the level of education given. 
#for this task we need to fileter through one of the three: Primary, Secondry, High(school)

school.school_level.unique()
# Out:
# array(['4-Other', '1-Primary', nan, '3-High', '2-Middle'], dtype=object)

# %% [markdown]
# ### Question 1. chose only High Shcools within the school data

# %%
print "# of primary schools:", len(school[school['school_level']=='1-Primary'])
print "# of secondary schools:", len(school[school['school_level']=='2-Middle'])
print "# of high schools:", len(school[school['school_level']=='3-High'])
#school['school_level']=='1-Primary'
# Out:
# # of primary schools: 53222
# # of secondary schools: 16687
# # of high schools: 20756

# %%
#let's chose only High schools :

high_s = (school[school['school_level']=='3-High'])

# %%
high_s[50:52]
# Out:
#                     School Name  \
# 313      GEORGE MORGAN SR. H.S.
# 350  KUSKOKWIM LEARNING ACADEMY
#
#     State Name [Public School] Latest available year  \
# 313                                           Alaska
# 350                                           Alaska
#
#     State Abbr [Public School] Latest available year  studyID  instudy  \
# 313                                              AK         0        0
# 350                                              AK         0        0
#
#      School ID - NCES Assigned [Public School] Latest available year  \
# 313                                        20076000665
# 350                                        20000100318
#
#     Agency Name [Public School] 2013-14  \
# 313              KUSPUK SCHOOL DISTRICT
# 350     LOWER KUSKOKWIM SCHOOL DISTRICT
#
#      Agency ID - NCES Assigned [Public School] Latest available year  \
# 313                                             200760
# 350                                             200001
#
#     School Type [Public School] 2013-14 Agency Type [District] 2013-14  \
# 313                    1-Regular school        1-Local school district
# 350          4-Alternative/other school        1-Local school district
#
#        ...    Black Students [Public School] 2013-14  \
# 313    ...                                         0
# 350    ...                                         2
#
#     White Students [Public School] 2013-14  \
# 313                                      0
# 350                                      1
#
#     Hawaiian Nat./Pacific Isl. Students [Public School] 2013-14  \
# 313                                                  0
# 350                                                  0
#
#     Two or More Races Students [Public School] 2013-14  \
# 313                                                  0
# 350                                                  0
#
#     Full-Time Equivalent (FTE) Teachers [Public School] 2013-14  \
# 313                                                4.3
# 350                                                6.0
#
#     Pupil/Teacher Ratio [Public School] 2013-14                 school_type  \
# 313                                       14.65            1-Regular school
# 350                                       13.00  4-Alternative/other school
#
#           grade school_level agency_id
# 313  12th Grade       3-High    200760
# 350  12th Grade       3-High    200001
#
# [2 rows x 51 columns]

# %%
#change agency ID name ot fit to 

high_s['agency_id']= high_s['Agency ID - NCES Assigned [Public School] Latest available year']
dis['agency_id']= dis['Agency ID - NCES Assigned [District] Latest available year']
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# ### Question 2. Merge District into School data (only High)

# %%
merge_sd = pd.merge (dis,high_s,  how='inner', on=['agency_id'])

# %%
len(merge_sd)
# Out:
# 20756

# %%
merge_sd[60:62]
# Out:
#             Agency Name State Name [District] Latest available year  \
# 60  ACALANES UNION HIGH                                  California
# 61  ACALANES UNION HIGH                                  California
#
#    State Abbr [District] Latest available year  \
# 60                                         CA
# 61                                         CA
#
#     Agency ID - NCES Assigned [District] Latest available year  \
# 60                                             601650
# 61                                             601650
#
#     Total Number Operational Schools [Public School] 2013-14  \
# 60                                                  5
# 61                                                  5
#
#     Total Number Operational Charter Schools [Public School] 2013-14  \
# 60                                                  0
# 61                                                  0
#
#     Total Number of Public Schools [Public School] 2013-14  \
# 60                                                  5
# 61                                                  5
#
#    Agency Type [District] 2013-14_x Urban-centric Locale [District] 2013-14  \
# 60          1-Local school district                        21-Suburb: Large
# 61          1-Local school district                        21-Suburb: Large
#
#    Metro Micro Area Code [District] 2013-14     ...      \
# 60                      1-Metropolitan Area     ...
# 61                      1-Metropolitan Area     ...
#
#    Full-Time Equivalent (FTE) Teachers [Public School] 2013-14_y  \
# 60                                               60.0
# 61                                               73.4
#
#    Pupil/Teacher Ratio [Public School] 2013-14_y       school_type  \
# 60                                         21.00  1-Regular school
# 61                                         21.09  1-Regular school
#
#          grade  school_level  agency_t    f    m  index  g_interval
# 60  12th Grade        3-High         1  614  646     60    0.512698
# 61  12th Grade        3-High         1  756  792     61    0.511628
#
# [2 rows x 95 columns]

# %%
#make sure the marge worked: 

print"number of columns in the district file ", len(dis.columns)
print"number of columns in the district file ", len(high_s.columns)
print "number of columns MERGED", len(merge_sd.columns)
# Out:
# number of columns in the district file  40
# number of columns in the district file  51
# number of columns MERGED 90

# %% [markdown]
# It worked !

# %% [markdown]
# ###  Q's 3+4 are both intertwined in the below code. I marked in numbers (1,2,3) Q3 : recode 5 variables. And in letters (A,B,C) Q4 : summary table or figure with descriptive stats for at least 4 variables

# %% [markdown]
# now let's play around with the data --

# %% [markdown]
# Recode variables and then plot them

# %% [markdown]
# #### 1. reduce the type of schools wording so that we get this format: X-School_type , onstead of the inital structure
# #rename agency type

# %%
merge_sd['agency_t'] = merge_sd['Agency Type [District] 2013-14_x']

# %%
merge_sd.agency_t.unique()
# Out:
# array(['4-Regional education services agency', '1-Local school district',
#        '7-Charter school agency', '5-State-operated institution',
#        '8-Other education agency',
#        '2-Local school district component of supervisory union',
#        '3-Supervisory union administrative center'], dtype=object)

# %% [markdown]
# #### 2. add comas b/w words

# %%
merge_sd['agency_t'] = merge_sd['agency_t'].apply(lambda x: x.split(' ')[0])

# %%
print merge_sd.agency_t.head(3)
# Out:
# 0    4-Regional
# 1       1-Local
# 2       1-Local
# Name: agency_t, dtype: object

# %%
# only keep the integer
merge_sd['agency_t'] = merge_sd['agency_t'].apply(lambda x: x.split('-')[0])

# %%
#merge_sd['agency_t'][0][0]
print merge_sd.agency_t.head(3)
# Out:
# 0    4
# 1    1
# 2    1
# Name: agency_t, dtype: object

# %%
merge_sd.agency_t.dtypes
# Out:
# dtype('O')

# %%
# change data type to integers to plot 
types = pd.DataFrame(columns=['agency_t'], dtype=float)

# %%
types.agency_t.dtypes
# Out:
# dtype('float64')

# %%
#merge_sd.columns

# %% [markdown]
# desrptivies for # females in public shools:

# %% [markdown]
# #### 3. change column name  for female
# #### A. get descriptives  for female

# %%
#merge_sd['multi'] = merge_sd['Two or More Races Students [Public School] 2013-14_y']

merge_sd['f'] = merge_sd['Female Students [Public School] 2013-14_y']

merge_sd['f'].describe()
# Out:
# count    19450.000000
# mean       352.641234
# std        362.040863
# min          0.000000
# 25%         76.000000
# 50%        217.000000
# 75%        545.000000
# max       2454.000000
# Name: f, dtype: float64

# %% [markdown]
# #### 4. change column name  for female
#
# ##### B. get descriptives fpr males

# %% [markdown]
# desrptivies for # males in public shools:

# %%
merge_sd['m'] = merge_sd['Male Students [Public School] 2013-14_y']

merge_sd['m'].describe()
# Out:
# count    19450.000000
# mean       368.612442
# std        374.904621
# min          0.000000
# 25%         82.000000
# 50%        226.000000
# 75%        568.000000
# max       3197.000000
# Name: m, dtype: float64

# %% [markdown]
# #### 5. create a new column from the indes #

# %%
merge_sd['index'] = merge_sd.index

# %% [markdown]
# #### C. plot female / males # per school

# %%
plt.figure(figsize=(36,12))
plt.xlim([1,19450])
plt.xlabel('# per school by Gender', size = 30)
plt.title('females vs males in schools: green females, red males ', size =50)
plt.plot( merge_sd.index ,merge_sd.m, 'ro',merge_sd.index,merge_sd.f,'g^')
plt.show()
#plt.plot(t, t, 'r--', t, t**2, 'bs', t)

# %% [markdown]
# this table diaplays the number of females and males in each school.
# green = females
# red = males
#
# This is viz isn't doing a great job in showing what is the dieffrence in quantities between both sexes (there are MANY schools, the dots overlap each other etc).
#
# However it does look like overall red tend to get higher and green is more conentrated on the bottom, so it seems like most school have more males than females. This information is validated when looking at the desciptitives for both genders:
#
# the females mean is

# %%
#merge_sd['index1'].describe()

# %% [markdown]
# #### 6. create a new column using both females and males

# %%
#the share of females in schools 
merge_sd['g_interval'] = merge_sd['m'] / (merge_sd['f']+merge_sd['m'])

# %% [markdown]
# ##### D. descirptives for the new interval column

# %%
merge_sd['g_interval'].describe()
# Out:
# count    19289.000000
# mean         0.524782
# std          0.101221
# min          0.000000
# 25%          0.494099
# 50%          0.514056
# 75%          0.538462
# max          1.000000
# Name: g_interval, dtype: float64

# %% [markdown]
# #### E. plot the ratio of females in schools: 0-1

# %%
plt.figure(figsize=(15,17))
plt.xlim([1,19450])
plt.ylim([0,1])

plt.plot(merge_sd.g_interval)
#plt.axvline(y=.5, color = 'k')
